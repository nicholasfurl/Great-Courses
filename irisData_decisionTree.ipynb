# %% [markdown]
# <a href="https://colab.research.google.com/github/nicholasfurl/Great-Courses/blob/main/irisData_decisionTree.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
x=1

# %%
from sklearn import datasets

# %%
iris = datasets.load_iris()

# %%
irisData = iris.data
irisLabels = iris.target
irisFeats = iris.feature_names

# %%
from sklearn import tree
import graphviz

# %%
#So I can play with number of leaves

#Just so I can recycle code with different variable names
dat = irisData
labs = irisLabels
feats = irisFeats

#run model fit
num_leaves = 3
clf = tree.DecisionTreeClassifier(max_leaf_nodes = num_leaves)	
clf = clf.fit(dat, labs)

#Get proportion correct
correct = 0						
for i in range(len(dat)):	
    if clf.predict([dat[i]]) == labs[i]: correct = correct + 1
print('proportion correct: ' + str(100.0* correct / len(dat)))

#configure info / labels for graphics object
dot_data = tree.export_graphviz(clf, feature_names=feats,
                      filled=True, rounded=True)

#create graphics source object and graph it
graph = graphviz.Source(dot_data)	
graph
# Out:
# proportion correct: 96.0
